# %%
import pandas as pd
import numpy as np

# Load the data
data = pd.read_csv(r'C:\Users\cheng\Documents\GitHub\Data_Mining_Project\UMA_IE500_Data_Mining\hotel_booking_data\hotel_bookings.csv')
data_origiin = pd.read_csv(r'C:\Users\cheng\Documents\GitHub\Data_Mining_Project\UMA_IE500_Data_Mining\hotel_booking_data\hotel_bookings.csv')
# Replace 'NULL' string values with real NaN
data.replace('NULL', np.nan, inplace=True)

# Convert date columns to datetime format
data['arrival_date'] = pd.to_datetime(
    data['arrival_date_year'].astype(str) + '-' +
    data['arrival_date_month'].astype(str) + '-' +
    data['arrival_date_day_of_month'].astype(str),
    errors='coerce'
)

# Drop redundant date parts (optional)
# data.drop(['arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month'], axis=1, inplace=True)

# Convert categorical and numeric columns
categorical_cols = data.select_dtypes(include='object').columns
numeric_cols = data.select_dtypes(include='number').columns

# Optional: fix boolean style numeric values
data['is_canceled'] = data['is_canceled'].astype(int)

# Overview of cleaned data
#print(data.info())
#print("\nMissing values per column:\n", data.isnull().sum())
#print("\nSample rows:\n", data.head())

# %%
# Show as table
pd.set_option('display.max_columns', None)  # show all columns
pd.set_option('display.width', 1000)        # wider display
display(data.head(10))  # show the first 10 rows as a table
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  adults  children  babies meal country market_segment distribution_channel  is_repeated_guest  previous_cancellations  previous_bookings_not_canceled reserved_room_type assigned_room_type  booking_changes deposit_type  agent  company  days_in_waiting_list customer_type    adr  required_car_parking_spaces  total_of_special_requests reservation_status reservation_status_date arrival_date
# ...

# %%
# save the data with the arrival date column
data.to_csv(r'C:\Users\cheng\Documents\GitHub\Data_Mining_Project\UMA_IE500_Data_Mining\hotel_booking_data\hotel_bookings_with_specific_arrival_date.csv', index=False)
